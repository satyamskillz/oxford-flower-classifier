# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# The new version of dataset is only available in the tfds-nightly package.
# %pip --no-cache-dir install tfds-nightly --user
# !pip --no-cache-dir install tfds-nightly
# DON'T MISS TO RESTART THE KERNEL
# Out:
# Requirement already satisfied: tfds-nightly in /root/.local/lib/python3.7/site-packages (3.1.0.dev202005310105)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (4.36.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.12.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (2.22.0)
# Requirement already satisfied: promise in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (2.2.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (0.18.2)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (3.11.2)
# Requirement already satisfied: tensorflow-metadata<0.16,>=0.15 in /root/.local/lib/python3.7/site-packages (from tfds-nightly) (0.15.2)
# Requirement already satisfied: attrs>=18.1.0 in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (19.3.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.11.2)
# Requirement already satisfied: dill in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (0.3.1.1)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (0.8.1)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.1.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.17.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (2.8)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.6.1->tfds-nightly) (41.4.0)
# Requirement already satisfied: googleapis-common-protos in /opt/conda/lib/python3.7/site-packages (from tensorflow-metadata<0.16,>=0.15->tfds-nightly) (1.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tfds-nightly in /root/.local/lib/python3.7/site-packages (3.1.0.dev202005310105)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (4.36.1)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.11.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.17.4)
# Requirement already satisfied: dill in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (0.3.1.1)
# Requirement already satisfied: promise in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (2.2.1)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (3.11.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.12.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (2.22.0)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (0.8.1)
# Requirement already satisfied: attrs>=18.1.0 in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (19.3.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (1.1.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from tfds-nightly) (0.18.2)
# Requirement already satisfied: tensorflow-metadata<0.16,>=0.15 in /root/.local/lib/python3.7/site-packages (from tfds-nightly) (0.15.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.6.1->tfds-nightly) (41.4.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly) (2019.11.28)
# Requirement already satisfied: googleapis-common-protos in /opt/conda/lib/python3.7/site-packages (from tensorflow-metadata<0.16,>=0.15->tfds-nightly) (1.6.0)

# %%
# Import TensorFlow 
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub

# %%
# TODO: Make all other necessary imports.
import json
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# Download data to default local directory "~/tensorflow_datasets"
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums=True --datasets=oxford_flowers102

# TODO: Load the dataset with TensorFlow Datasets. Hint: use tfds.load()
dataset, dataset_info=tfds.load("oxford_flowers102",as_supervised=True, with_info=True)
# TODO: Create a training set, a validation set and a test set.
training_set, test_set, valid_set = dataset["train"], dataset["test"], dataset["validation"]
# Out:
# I0601 02:29:42.837361 139886350702336 download_and_prepare.py:201] Running download_and_prepare for dataset(s):
# oxford_flowers102
# I0601 02:29:42.891826 139886350702336 dataset_info.py:427] Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: oxford_flowers102/2.1.1
# I0601 02:29:42.957026 139886350702336 dataset_info.py:358] Load dataset info from /tmp/tmp1hbys0extfds
# I0601 02:29:42.968045 139886350702336 download_and_prepare.py:139] download_and_prepare for dataset oxford_flowers102/2.1.1...
# I0601 02:29:42.968449 139886350702336 dataset_builder.py:345] Generating dataset oxford_flowers102 (/root/tensorflow_datasets/oxford_flowers102/2.1.1)
# Downloading and preparing dataset oxford_flowers102/2.1.1 (download: 328.90 MiB, generated: 331.34 MiB, total: 660.25 MiB) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0601 02:29:43.070454 139886350702336 download_manager.py:477] Downloading https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz into /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_102flowersoWedSp98maBn1wypsDib6T-q2NVbO40fwvTflmPmQpY.tgz.tmp.1b3cd937b3d446869c4a93a4f3b7ab1c...
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0601 02:29:43.072931 139886350702336 download_manager.py:466] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat already downloaded: reusing /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat.
# I0601 02:29:43.073374 139886350702336 download_manager.py:496] Skipping extraction for /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat (method=NO_EXTRACT).
# I0601 02:29:43.073815 139886350702336 download_manager.py:466] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/setid.mat already downloaded: reusing /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat.
# I0601 02:29:43.074184 139886350702336 download_manager.py:496] Skipping extraction for /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat (method=NO_EXTRACT).
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   0%|                                     | 0/328 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   0%|                             | 1/328 [00:01<05:56,  1.09s/ MiB]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   1%|▏                            | 2/328 [00:01<04:19,  1.26 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   1%|▎                            | 3/328 [00:01<04:18,  1.26 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   1%|▎                            | 4/328 [00:01<03:05,  1.75 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   2%|▍                            | 5/328 [00:01<03:04,  1.75 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   2%|▌                            | 6/328 [00:01<02:14,  2.40 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   2%|▌                            | 7/328 [00:01<02:13,  2.40 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   2%|▋                            | 8/328 [00:01<02:13,  2.40 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   3%|▊                            | 9/328 [00:01<01:36,  3.31 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   3%|▊                           | 10/328 [00:01<01:36,  3.31 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   3%|▉                           | 11/328 [00:01<01:35,  3.31 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   4%|█                           | 12/328 [00:01<01:35,  3.31 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   4%|█                           | 13/328 [00:01<01:10,  4.48 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   4%|█▏                          | 14/328 [00:01<01:10,  4.48 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   5%|█▎                          | 15/328 [00:01<01:09,  4.48 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   5%|█▎                          | 16/328 [00:01<01:09,  4.48 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   5%|█▍                          | 17/328 [00:01<00:51,  6.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   5%|█▌                          | 18/328 [00:01<00:51,  6.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   6%|█▌                          | 19/328 [00:01<00:51,  6.02 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   6%|█▋                          | 20/328 [00:01<00:39,  7.88 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   6%|█▊                          | 21/328 [00:01<00:38,  7.88 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   7%|█▉                          | 22/328 [00:01<00:38,  7.88 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   7%|█▉                          | 23/328 [00:02<00:30, 10.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   7%|██                          | 24/328 [00:02<00:30, 10.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   8%|██▏                         | 25/328 [00:02<00:30, 10.09 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   8%|██▏                         | 26/328 [00:02<00:24, 12.55 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   8%|██▎                         | 27/328 [00:02<00:23, 12.55 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   9%|██▍                         | 28/328 [00:02<00:23, 12.55 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   9%|██▍                         | 29/328 [00:02<00:19, 15.12 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   9%|██▌                         | 30/328 [00:02<00:19, 15.12 MiB/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   9%|██▋                         | 31/328 [00:02<00:19, 15.12 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  10%|██▋                         | 32/328 [00:02<00:16, 17.68 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  10%|██▊                         | 33/328 [00:02<00:16, 17.68 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  10%|██▉                         | 34/328 [00:02<00:16, 17.68 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  11%|██▉                         | 35/328 [00:02<00:14, 20.03 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  11%|███                         | 36/328 [00:02<00:14, 20.03 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  11%|███▏                        | 37/328 [00:02<00:14, 20.03 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  12%|███▏                        | 38/328 [00:02<00:13, 22.13 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  12%|███▎                        | 39/328 [00:02<00:13, 22.13 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  12%|███▍                        | 40/328 [00:02<00:13, 22.13 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  12%|███▌                        | 41/328 [00:02<00:12, 23.41 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  13%|███▌                        | 42/328 [00:02<00:12, 23.41 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  13%|███▋                        | 43/328 [00:02<00:12, 23.41 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  13%|███▊                        | 44/328 [00:02<00:11, 24.94 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  14%|███▊                        | 45/328 [00:02<00:11, 24.94 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  14%|███▉                        | 46/328 [00:02<00:11, 24.94 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  14%|████                        | 47/328 [00:02<00:10, 26.21 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  15%|████                        | 48/328 [00:02<00:10, 26.21 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  15%|████▏                       | 49/328 [00:02<00:10, 26.21 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  15%|████▎                       | 50/328 [00:02<00:10, 25.74 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  16%|████▎                       | 51/328 [00:02<00:10, 25.74 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  16%|████▍                       | 52/328 [00:03<00:10, 25.74 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  16%|████▌                       | 53/328 [00:03<00:10, 25.74 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  16%|████▌                       | 54/328 [00:03<00:10, 26.35 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  17%|████▋                       | 55/328 [00:03<00:10, 26.35 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  17%|████▊                       | 56/328 [00:03<00:10, 26.35 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  17%|████▊                       | 57/328 [00:03<00:10, 26.35 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  18%|████▉                       | 58/328 [00:03<00:09, 28.05 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  18%|█████                       | 59/328 [00:03<00:09, 28.05 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  18%|█████                       | 60/328 [00:03<00:09, 28.05 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  19%|█████▏                      | 61/328 [00:03<00:09, 28.04 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  19%|█████▎                      | 62/328 [00:03<00:09, 28.04 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  19%|█████▍                      | 63/328 [00:03<00:09, 28.04 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  20%|█████▍                      | 64/328 [00:03<00:09, 27.87 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  20%|█████▌                      | 65/328 [00:03<00:09, 27.87 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  20%|█████▋                      | 66/328 [00:03<00:09, 27.87 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  20%|█████▋                      | 67/328 [00
MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  55%|██████████████▉            | 181/328 [00:07<00:05, 28.52 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  55%|██████████████▉            | 182/328 [00:07<00:05, 28.52 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  56%|███████████████            | 183/328 [00:07<00:05, 28.52 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  56%|███████████████▏           | 184/328 [00:07<00:05, 28.11 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  56%|███████████████▏           | 185/328 [00:07<00:05, 28.11 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  57%|███████████████▎           | 186/328 [00:07<00:05, 28.11 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  57%|███████████████▍           | 187/328 [00:07<00:05, 28.11 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  57%|███████████████▍           | 188/328 [00:07<00:04, 29.12 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  58%|███████████████▌           | 189/328 [00:07<00:04, 29.12 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  58%|███████████████▋           | 190/328 [00:07<00:04, 29.12 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  58%|███████████████▋           | 191/328 [00:07<00:04, 29.24 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  59%|███████████████▊           | 192/328 [00:07<00:04, 29.24 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  59%|███████████████▉           | 193/328 [00:07<00:04, 29.24 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:  59%|███████████████▉           | 194/328 [00:07<00:04, 29.24 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  59%|████████████████           | 195/328 [00:08<00:04, 28.03 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  60%|████████████████▏          | 196/328 [00:08<00:04, 28.03 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  60%|████████████████▏          | 197/328 [00:08<00:04, 28.03 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  60%|████████████████▎          | 198/328 [00:08<00:04, 28.29 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  61%|████████████████▍          | 199/328 [00:08<00:04, 28.29 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  61%|████████████████▍          | 200/328 [00:08<00:04, 28.29 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  61%|████████████████▌          | 201/328 [00:08<00:04, 28.29 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  62%|████████████████▋          | 202/328 [00:08<00:04, 29.27 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  62%|████████████████▋          | 203/328 [00:08<00:04, 29.27 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  62%|████████████████▊          | 204/328 [00:08<00:04, 29.27 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  62%|████████████████▉          | 205/328 [00:08<00:04, 29.28 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  63%|████████████████▉          | 206/328 [00:08<00:04, 29.28 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  63%|█████████████████          | 207/328 [00:08<00:04, 29.28 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  63%|█████████████████          | 208/328 [00:08<00:04, 26.94 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  64%|█████████████████▏         | 209/328 [00:08<00:04, 26.94 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  64%|█████████████████▎         | 210/328 [00:08<00:04, 26.94 MiB/s]
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  64%|█████████████████▎         | 211/328 [00:08<00:04, 27.57 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  65%|█████████████████▍         | 212/328 [00:08<00:04, 27.57 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  65%|█████████████████▌         | 213/328 [00:08<00:04, 27.57 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  65%|█████████████████▌         | 214/328 [00:08<00:04, 27.57 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  66%|█████████████████▋         | 215/328 [00:08<00:04, 28.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  66%|█████████████████▊         | 216/328 [00:08<00:03, 28.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  66%|█████████████████▊         | 217/328 [00:08<00:03, 28.02 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  66%|█████████████████▉         | 218/328 [00:08<00:03, 28.41 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  67%|██████████████████         | 219/328 [00:08<00:03, 28.41 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  67%|██████████████████         | 220/328 [00:08<00:03, 28.41 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  67%|██████████████████▏        | 221/328 [00:08<00:03, 28.59 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:  68%|██████████████████▎        | 222/328 [00:08<00:03, 28.59 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  68%|██████████████████▎        | 223/328 [00:09<00:03, 28.59 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  68%|██████████████████▍        | 224/328 [00:09<00:03, 28.59 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  69%|██████████████████▌        | 225/328 [00:09<00:03, 28.74 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  69%|██████████████████▌        | 226/328 [00:09<00:03, 28.74 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  69%|██████████████████▋        | 227/328 [00:09<00:03, 28.74 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  70%|██████████████████▊        | 228/328 [00:09<00:03, 29.07 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  70%|██████████████████▊        | 229/328 [00:09<00:03, 29.07 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  70%|██████████████████▉        | 230/328 [00:09<00:03, 29.07 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  70%|███████████████████        | 231/328 [00:09<00:03, 29.07 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  71%|███████████████████        | 232/328 [00:09<00:03, 28.41 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  71%|███████████████████▏       | 233/328 [00:09<00:03, 28.41 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  71%|███████████████████▎       | 234/328 [00:09<00:03, 28.41 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  72%|███████████████████▎       | 235/328 [00:09<00:03, 28.55 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  72%|███████████████████▍       | 236/328 [00:09<00:03, 28.55 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  72%|███████████████████▌       | 237/328 [00:09<00:03, 28.55 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  73%|███████████████████▌       | 238/328 [00:09<00:03, 28.66 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  73%|███████████████████▋       | 239/328 [00:09<00:03, 28.66 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  73%|███████████████████▊       | 240/328 [00:09<00:03, 28.66 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  73%|███████████████████▊       | 241/328 [00:09<00:03, 28.66 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  74%|███████████████████▉       | 242/328 [00:09<00:02, 29.81 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  74%|████████████████████       | 243/328 [00:09<00:02, 29.81 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  74%|████████████████████       | 244/328 [00:09<00:02, 29.81 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  75%|████████████████████▏      | 245/328 [00:09<00:02, 28.94 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  75%|████████████████████▎      | 246/328 [00:09<00:02, 28.94 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  75%|████████████████████▎      | 247/328 [00:09<00:02, 28.94 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  76%|████████████████████▍      | 248/328 [00:09<00:02, 28.95 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  76%|████████████████████▍      | 249/328 [00:09<00:02, 28.95 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  76%|████████████████████▌      | 250/328 [00:09<00:02, 28.95 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:  77%|████████████████████▋      | 251/328 [00:09<00:02, 28.57 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:10<?, ? url/s]
# Dl Size...:  77%|████████████████████▋      | 252/328 [00:10<00:02, 28.57 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:10<?, ? url/s]
# Dl Size...:  77%|████████████████████▊      | 253/328 [00:10<00:02, 28.57 MiB/s]
#
# ...
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         mean: 50.5
#         std_dev: 29.443448620476957
#         num_zeros: 10
#         median: 51.0
#         max: 101.0
#         histograms {
#           buckets {
#             high_value: 10.1
#             sample_count: 109.242
#           }
#           buckets {
#             low_value: 10.1
#             high_value: 20.2
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 20.2
#             high_value: 30.299999999999997
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 30.299999999999997
#             high_value: 40.4
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 40.4
#             high_value: 50.5
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 50.5
#             high_value: 60.599999999999994
#             sample_count: 101.08200000000001
#           }
#           buckets {
#             low_value: 60.599999999999994
#             high_value: 70.7
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 70.7
#             high_value: 80.8
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 80.8
#             high_value: 90.89999999999999
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 90.89999999999999
#             high_value: 101.0
#             sample_count: 109.242
#           }
#         }
#         histograms {
#           buckets {
#             high_value: 10.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 10.0
#             high_value: 20.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 20.0
#             high_value: 30.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 30.0
#             high_value: 40.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 40.0
#             high_value: 51.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 51.0
#             high_value: 61.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 61.0
#             high_value: 71.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 71.0
#             high_value: 81.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 81.0
#             high_value: 91.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 91.0
#             high_value: 101.0
#             sample_count: 102.0
#           }
#           type: QUANTILES
#         }
#       }
#       path {
#         step: "label"
#       }
#     }
#   }
#   shard_lengths: 1020
#   num_bytes: 43474584
# }
# splits {
#   name: "validation"
#   statistics {
#     num_examples: 1020
#     features {
#       type: STRING
#       string_stats {
#         common_stats {
#           num_non_missing: 1020
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         unique: 1020
#         top_values {
#           value: "image_08187.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08185.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08182.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08179.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08176.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08174.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08173.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08157.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08138.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08133.jpg"
#           frequency: 1.0
#         }
#         avg_length: 15.0
#         rank_histogram {
#           buckets {
#             label: "image_08187.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 1
#             high_rank: 1
#             label: "image_08185.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 2
#             high_rank: 2
#             label: "image_08182.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 3
#             high_rank: 3
#             label: "image_08179.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 4
#             high_rank: 4
#             label: "image_08176.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 5
#             high_rank: 5
#             label: "image_08174.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 6
#             high_rank: 6
#             label: "image_08173.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 7
#             high_rank: 7
#             label: "image_08157.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 8
#             high_rank: 8
#             label: "image_08138.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 9
#             high_rank: 9
#             label: "image_08133.jpg"
#             sample_count: 1.0
#           }
#         }
#       }
#       path {
#         step: "file_name"
#       }
#     }
#     features {
#       type: STRING
#       string_stats {
#         common_stats {
#           num_non_missing: 1020
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         unique: 1020
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         avg_length: 42256.625
#         rank_histogram {
#           buckets {
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 1
#             high_rank: 1
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 2
#             high_rank: 2
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 3
#             high_rank: 3
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 4
#             high_rank: 4
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 5
#             high_rank: 5
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 6
#             high_rank: 6
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 7
#             high_rank: 7
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 8
#             high_rank: 8
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 9
#             high_rank: 9
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#         }
#       }
#       path {
#         step: "image"
#       }
#     }
#     features {
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         mean: 50.5
#         std_dev: 29.443448620476957
#         num_zeros: 10
#         median: 51.0
#         max: 101.0
#         histograms {
#           buckets {
#             high_value: 10.1
#             sample_count: 109.242
#           }
#           buckets {
#             low_value: 10.1
#             high_value: 20.2
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 20.2
#             high_value: 30.299999999999997
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 30.299999999999997
#             high_value: 40.4
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 40.4
#             high_value: 50.5
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 50.5
#             high_value: 60.599999999999994
#             sample_count: 101.08200000000001
#           }
#           buckets {
#             low_value: 60.599999999999994
#             high_value: 70.7
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 70.7
#             high_value: 80.8
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 80.8
#             high_value: 90.89999999999999
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 90.89999999999999
#             high_value: 101.0
#             sample_count: 109.242
#           }
#         }
#         histograms {
#           buckets {
#             high_value: 10.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 10.0
#             high_value: 20.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 20.0
#             high_value: 30.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 30.0
#             high_value: 40.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 40.0
#             high_value: 51.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 51.0
#             high_value: 61.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 61.0
#             high_value: 71.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 71.0
#             high_value: 81.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 81.0
#             high_value: 91.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 91.0
#             high_value: 101.0
#             sample_count: 102.0
#           }
#           type: QUANTILES
#         }
#       }
#       path {
#         step: "label"
#       }
#     }
#   }
#   shard_lengths: 1020
#   num_bytes: 43180278
# }
# supervised_keys {
#   input: "image"
#   output: "label"
# }
# version: "2.1.1"
# download_size: 344878000

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.
num_training_example=dataset_info.splits["train"].num_examples
num_test_example=dataset_info.splits["test"].num_examples

num_validation_example=dataset_info.splits["validation"].num_examples
# TODO: Get the number of classes in the dataset from the dataset info.
num_classes=dataset_info.features["label"].num_classes

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
for image, label in training_set.take(3):
    print("Shape of image: {}, Label of image: {}".format(image.shape,label.numpy()))
# Out:
# Shape of image: (500, 667, 3), Label of image: 72
# Shape of image: (500, 666, 3), Label of image: 84
# Shape of image: (670, 500, 3), Label of image: 70

# %%
# TODO: Plot 1 image from the training set. 
# Set the title of the plot to the corresponding image label. 
for image, label in training_set.take(1):
    image=image.numpy().squeeze()
    label=label.numpy()
    plt.imshow(image)
    plt.title("Label-{}".format(label))
    plt.show

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
with open('label_map.json', 'r') as f:
    class_names = json.load(f)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
for image, label in training_set.take(1):
    image=image.numpy().squeeze()
    label=label.numpy()
    image_name=class_names[str(label)]
    plt.imshow(image)
    plt.title(image_name)
    plt.show()

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.
batch_size=64
image_size=224
def normalize(img,label):
    x = np.random.randint(0, 3)
    if x == 0:
        img = tf.image.rot90(img, k=np.random.randint(1, 4))
    elif x == 1:
        img = tf.image.random_flip_left_right(img)
    image=tf.image.resize(img,(image_size,image_size), method= tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    img=tf.cast(img, tf.float32)
    image/=255
    return image, label
training_batches=training_set.shuffle(num_training_example//4).map(normalize).batch(batch_size).prefetch(1)
test_batches=test_set.map(normalize).batch(batch_size).prefetch(1)
vaild_batches=valid_set.map(normalize).batch(batch_size).prefetch(1)

# %%
for image_batch, label_batch in training_batches.take(1):
    print(image_batch.shape,label_batch.shape)
# Out:
# (64, 224, 224, 3) (64,)

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.
URL="https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobileNet=hub.KerasLayer(URL, input_shape=(image_size,image_size,3))
mobileNet.trainable=False

# %%
model= tf.keras.Sequential([
    mobileNet,
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(2*1024,activation ='relu'),
    tf.keras.layers.Dense(1024,activation ='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(512,activation ='relu'),
    tf.keras.layers.Dense(512,activation ='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(264,activation ='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(102,activation="softmax")
])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 1280)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 2048)              2623488
# _________________________________________________________________
# dense_35 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 264)               135432
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 264)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 102)               27030
# =================================================================
# Total params: 7,929,566
# Trainable params: 5,671,582
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
print("Is there is GPU available:",tf.test.is_gpu_available())
adam=tf.optimizers.Adam(learning_rate=0.00005)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=adam,
              metrics=["accuracy"])
# Out:
# Is there is GPU available: True

# %%
early_stop=tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                            patience=5)
save_best=tf.keras.callbacks.ModelCheckpoint("./best_model.h5",
                                             monitor="val_loss",
                                             save_best_only=True)
with tf.device("/GPU:0"):
    print("Training...")
    EPOCHS=100
    H=model.fit(training_batches,
                epochs=EPOCHS,
                callbacks=[early_stop],
                validation_data=vaild_batches)
# Out:
# Training...
# Epoch 1/100
# 16/16 [==============================] - 8s 496ms/step - loss: 4.6590 - accuracy: 0.0127 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 16/16 [==============================] - 5s 314ms/step - loss: 4.6139 - accuracy: 0.0108 - val_loss: 4.5832 - val_accuracy: 0.0225
# Epoch 3/100
# 16/16 [==============================] - 5s 321ms/step - loss: 4.5896 - accuracy: 0.0225 - val_loss: 4.5642 - val_accuracy: 0.0373
# Epoch 4/100
# 16/16 [==============================] - 5s 316ms/step - loss: 4.5707 - accuracy: 0.0235 - val_loss: 4.5444 - val_accuracy: 0.0520
# Epoch 5/100
# 16/16 [==============================] - 5s 316ms/step - loss: 4.5311 - accuracy: 0.0314 - val_loss: 4.5103 - val_accuracy: 0.0804
# Epoch 6/100
# Epoch 25/100
# 16/16 [==============================] - 5s 317ms/step - loss: 2.3350 - accuracy: 0.4284 - val_loss: 1.9232 - val_accuracy: 0.5873
# Epoch 26/100
# 16/16 [==============================] - 5s 316ms/step - loss: 2.2055 - accuracy: 0.4422 - val_loss: 1.8404 - val_accuracy: 0.6078
# Epoch 27/100
# 16/16 [==============================] - 5s 315ms/step - loss: 2.1830 - accuracy: 0.4186 - val_loss: 1.7612 - val_accuracy: 0.6147
# Epoch 28/100
# 16/16 [==============================] - 5s 315ms/step - loss: 2.0076 - accuracy: 0.4882 - val_loss: 1.6698 - val_accuracy: 0.6441
# Epoch 29/100
# 16/16 [==============================] - 5s 320ms/step - loss: 1.9916 - accuracy: 0.4941 - val_loss: 1.6489 - val_accuracy: 0.6196
# Epoch 30/100
# 16/16 [==============================] - 5s 317ms/step - loss: 1.8226 - accuracy: 0.5490 - val_loss: 1.5802 - val_accuracy: 0.6500
# Epoch 31/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.7731 - accuracy: 0.5402 - val_loss: 1.5226 - val_accuracy: 0.6529
# Epoch 32/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.6433 - accuracy: 0.5863 - val_loss: 1.4612 - val_accuracy: 0.6627
# Epoch 33/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.6144 - accuracy: 0.5627 - val_loss: 1.4068 - val_accuracy: 0.6627
# Epoch 34/100
# 16/16 [==============================] - 5s 316ms/step - loss: 1.5520 - accuracy: 0.5794 - val_loss: 1.3526 - val_accuracy: 0.6843
# Epoch 35/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.4968 - accuracy: 0.6010 - val_loss: 1.3243 - val_accuracy: 0.6902
# Epoch 36/100
# 16/16 [==============================] - 5s 316ms/step - loss: 1.4702 - accuracy: 0.6186 - val_loss: 1.2882 - val_accuracy: 0.6980
# Epoch 37/100
# 16/16 [==============================] - 5s 320ms/step - loss: 1.4439 - accuracy: 0.6127 - val_loss: 1.2509 - val_accuracy: 0.7108
# Epoch 38/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.3620 - accuracy: 0.6431 - val_loss: 1.2313 - val_accuracy: 0.7010
# Epoch 39/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.3126 - accuracy: 0.6539 - val_loss: 1.2079 - val_accuracy: 0.6980
# Epoch 40/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.2870 - accuracy: 0.6471 - val_loss: 1.1875 - val_accuracy: 0.7069
# Epoch 41/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.2120 - accuracy: 0.6657 - val_loss: 1.1581 - val_accuracy: 0.7176
# Epoch 42/100
# 16/16 [==============================] - 5s 316ms/step - loss: 1.1989 - accuracy: 0.6706 - val_loss: 1.1483 - val_accuracy: 0.7186
# Epoch 43/100
# 16/16 [==============================] - 5s 314ms/step - loss: 1.1447 - accuracy: 0.6853 - val_loss: 1.1191 - val_accuracy: 0.7284
# Epoch 44/100
# 16/16 [==============================] - 5s 316ms/step - loss: 1.0751 - accuracy: 0.7147 - val_loss: 1.1070 - val_accuracy: 0.7206
# Epoch 45/100
# 16/16 [==============================] - 5s 314ms/step - loss: 1.0434 - accuracy: 0.6902 - val_loss: 1.0726 - val_accuracy: 0.7324
# Epoch 46/100
# 16/16 [==============================] - 5s 315ms/step - loss: 1.0365 - accuracy: 0.7216 - val_loss: 1.0684 - val_accuracy: 0.7343
# Epoch 47/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.9825 - accuracy: 0.7314 - val_loss: 1.0467 - val_accuracy: 0.7382
# Epoch 48/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.9272 - accuracy: 0.7422 - val_loss: 1.0295 - val_accuracy: 0.7265
# Epoch 49/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.9212 - accuracy: 0.7480 - val_loss: 1.0281 - val_accuracy: 0.7314
# Epoch 50/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.8918 - accuracy: 0.7559 - val_loss: 0.9977 - val_accuracy: 0.7412
# Epoch 51/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.9130 - accuracy: 0.7412 - val_loss: 0.9920 - val_accuracy: 0.7471
# Epoch 52/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.8261 - accuracy: 0.7814 - val_loss: 0.9870 - val_accuracy: 0.7451
# Epoch 53/100
# 16/16 [==============================] - 5s 321ms/step - loss: 0.8040 - accuracy: 0.7608 - val_loss: 0.9707 - val_accuracy: 0.7461
# Epoch 54/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.8022 - accuracy: 0.7863 - val_loss: 0.9871 - val_accuracy: 0.7549
# Epoch 55/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.7418 - accuracy: 0.7892 - val_loss: 0.9624 - val_accuracy: 0.7588
# Epoch 56/100
# 16/16 [==============================] - 5s 321ms/step - loss: 0.7462 - accuracy: 0.7892 - val_loss: 0.9533 - val_accuracy: 0.7559
# Epoch 57/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.7113 - accuracy: 0.8157 - val_loss: 0.9251 - val_accuracy: 0.7578
# Epoch 58/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.6870 - accuracy: 0.8137 - val_loss: 0.9360 - val_accuracy: 0.7588
# Epoch 59/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.7171 - accuracy: 0.8000 - val_loss: 0.9206 - val_accuracy: 0.7608
# Epoch 60/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.7278 - accuracy: 0.7931 - val_loss: 0.9156 - val_accuracy: 0.7637
# Epoch 61/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.6421 - accuracy: 0.8137 - val_loss: 0.9054 - val_accuracy: 0.7676
# Epoch 62/100
# 16/16 [==============================] - 5s 325ms/step - loss: 0.6284 - accuracy: 0.8216 - val_loss: 0.8815 - val_accuracy: 0.7804
# Epoch 63/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.6105 - accuracy: 0.8294 - val_loss: 0.9082 - val_accuracy: 0.7647
# Epoch 64/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.5952 - accuracy: 0.8343 - val_loss: 0.8804 - val_accuracy: 0.7706
# Epoch 65/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.5733 - accuracy: 0.8363 - val_loss: 0.8884 - val_accuracy: 0.7667
# Epoch 66/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.5359 - accuracy: 0.8480 - val_loss: 0.8740 - val_accuracy: 0.7765
# Epoch 67/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.5298 - accuracy: 0.8618 - val_loss: 0.8638 - val_accuracy: 0.7765
# Epoch 68/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.5419 - accuracy: 0.8392 - val_loss: 0.8851 - val_accuracy: 0.7618
# Epoch 69/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.5293 - accuracy: 0.8471 - val_loss: 0.8502 - val_accuracy: 0.7833
# Epoch 70/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.5405 - accuracy: 0.8490 - val_loss: 0.8528 - val_accuracy: 0.7863
# Epoch 71/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.5015 - accuracy: 0.8520 - val_loss: 0.8523 - val_accuracy: 0.7843
# Epoch 72/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.4496 - accuracy: 0.8833 - val_loss: 0.8376 - val_accuracy: 0.7853
# Epoch 73/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.4458 - accuracy: 0.8706 - val_loss: 0.8439 - val_accuracy: 0.7824
# Epoch 74/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.4432 - accuracy: 0.8755 - val_loss: 0.8490 - val_accuracy: 0.7843
# Epoch 75/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.4373 - accuracy: 0.8765 - val_loss: 0.8370 - val_accuracy: 0.7765
# Epoch 76/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.4031 - accuracy: 0.8990 - val_loss: 0.8371 - val_accuracy: 0.7814
# Epoch 77/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.4079 - accuracy: 0.8902 - val_loss: 0.8361 - val_accuracy: 0.7833
# Epoch 78/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.4093 - accuracy: 0.8892 - val_loss: 0.8304 - val_accuracy: 0.7804
# Epoch 79/100
# 16/16 [==============================] - 5s 321ms/step - loss: 0.4291 - accuracy: 0.8833 - val_loss: 0.8190 - val_accuracy: 0.7833
# Epoch 80/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.3970 - accuracy: 0.8863 - val_loss: 0.8277 - val_accuracy: 0.7755
# Epoch 81/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.3287 - accuracy: 0.9206 - val_loss: 0.8450 - val_accuracy: 0.7696
# Epoch 82/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.3608 - accuracy: 0.9049 - val_loss: 0.8214 - val_accuracy: 0.7725
# Epoch 83/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.3517 - accuracy: 0.9000 - val_loss: 0.8360 - val_accuracy: 0.7775
# Epoch 84/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.3458 - accuracy: 0.9078 - val_loss: 0.8431 - val_accuracy: 0.7824

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(84),H.history["val_accuracy"], label='Validation Accuracy')
plt.plot(range(84),H.history["accuracy"], label='Training Accuracy')
plt.legend(loc='upper left')
plt.subplot(1, 2, 2)
plt.plot(range(84),H.history["val_loss"],label='Validation Loss')
plt.plot(range(84),H.history["loss"],label='Training Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.
loss, accuracy = model.evaluate(test_batches)
# Out:
# 97/97 [==============================] - 14s 143ms/step - loss: 1.0200 - accuracy: 0.7403

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.
model.save("final_model.h5")

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model
reloaded_model=tf.keras.models.load_model("final_model.h5", custom_objects={'KerasLayer': hub.KerasLayer})

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function
def process_image(image):
    image = tf.convert_to_tensor(image,np.float32)
    image = tf.image.resize(image, (224, 224))
    image /= 255
    image = image.numpy()
    return image

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function
def predict(image_path, model, Top_k=5):
    
    img = Image.open(image_path)
    image = np.asarray(img)
    image = process_image(image)
    image=np.expand_dims(image, axis=0)
    
    output=model.predict(image)
    
    probs, classes= tf.math.top_k(output, Top_k)
    classes+=1
    class_list=[class_names[str(i)] for i in classes[0].numpy()]
    
    plt.figure(figsize=(16,4))
    plt.subplot(1,2,1)
    plt.imshow(img)
    plt.subplot(1,2,2)
    plt.barh(range(len(class_list)), probs[0].numpy(), align='center', alpha=0.5)
    plt.yticks(range(len(class_list)), class_list)
    plt.title("Class probability")
    plt.show()

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
image_path = './test_images/hard-leaved_pocket_orchid.jpg'
predict(image_path, reloaded_model)
